# %%
import os

base_dir = r'F:\University of Michigan Dropbox\Jiahui Chen\Ford_CC\Result_cc\Results_Y82_2024_rev'

folders_missing_csvs = []

for folder in os.listdir(base_dir):
    folder_path = os.path.join(base_dir, folder)
    if os.path.isdir(folder_path):
        csv_count = len([f for f in os.listdir(folder_path) if f.endswith('.csv')])
        if csv_count != 15:
            folders_missing_csvs.append((folder, csv_count))

print("Folders with missing or extra CSVs (not 15):")
for folder, count in folders_missing_csvs:
    print(f"{folder}: {count} csv files")

# %%
# List of required CSV files
import os
required_csvs = [
    '0_0_0_0_0_soc.csv', '0_0_0_10_0_soc.csv', '0_0_0_11_0_soc.csv', '0_0_0_12_0_soc.csv',
    '0_0_0_13_0_soc.csv', '0_0_0_14_0_soc.csv', '0_0_0_15_0_soc.csv', '0_0_0_16_0_soc.csv',
    '0_0_0_17_0_soc.csv', '0_0_0_18_0_soc.csv', '0_0_0_19_0_soc.csv', '0_0_0_1_0_soc.csv',
    '0_0_0_20_0_soc.csv', '0_0_0_21_0_soc.csv', '0_0_0_22_0_soc.csv'
]

# For each required file, also accept a version where 'soc' is replaced by '50'
required_csvs_with_50 = []
for fname in required_csvs:
    if fname.endswith('_soc.csv'):
        fname_50 = fname.replace('_soc.csv', '_50.csv')
        required_csvs_with_50.append((fname, fname_50))
    else:
        required_csvs_with_50.append((fname, None))

# Directories to check
dirs_to_check = [
    r'F:\University of Michigan Dropbox\Jiahui Chen\Ford_CC\Results\Results_80_82_rev',
    r'F:\University of Michigan Dropbox\Jiahui Chen\Ford_CC\Result_cc\Results_Y82_2024_rev',
    r'F:\University of Michigan Dropbox\Jiahui Chen\Ford_CC\Result_cc\Results_Y82_2030_rev',
    r'F:\University of Michigan Dropbox\Jiahui Chen\Ford_CC\Result_cc\Results_Y82_2040_rev',
    r'F:\University of Michigan Dropbox\Jiahui Chen\Ford_CC\Result_cc\Results_Y60_2024_nocarb',
    r'F:\University of Michigan Dropbox\Jiahui Chen\Ford_CC\Result_cc\Results_Y60_2030_nocarb',
    r'F:\University of Michigan Dropbox\Jiahui Chen\Ford_CC\Result_cc\Results_Y60_2040_nocarb',
    r'F:\University of Michigan Dropbox\Jiahui Chen\Ford_CC\Result_v2h\Results_80_Y60_2024_cons_nocarb',
    r'F:\University of Michigan Dropbox\Jiahui Chen\Ford_CC\Result_v2h\Results_80_Y60_2030_cons_nocarb',
    r'F:\University of Michigan Dropbox\Jiahui Chen\Ford_CC\Result_v2h\Results_80_Y60_2040_cons_nocarb',
    r'F:\University of Michigan Dropbox\Jiahui Chen\Ford_CC\Result_v2h\Results_80_Y60_2024_nocarb',
    r'F:\University of Michigan Dropbox\Jiahui Chen\Ford_CC\Result_v2h\Results_80_Y60_2030_nocarb',
    r'F:\University of Michigan Dropbox\Jiahui Chen\Ford_CC\Result_v2h\Results_80_Y60_2040_nocarb',
    r'F:\University of Michigan Dropbox\Jiahui Chen\Ford_CC\Result_v2h\Results_80_Y82_2024_cons_nocarb',
    r'F:\University of Michigan Dropbox\Jiahui Chen\Ford_CC\Result_v2h\Results_80_Y82_2030_cons_nocarb',
    r'F:\University of Michigan Dropbox\Jiahui Chen\Ford_CC\Result_v2h\Results_80_Y82_2040_cons_nocarb',
    r'F:\University of Michigan Dropbox\Jiahui Chen\Ford_CC\Result_v2h\Results_80_Y82_2024_nocarb',
    r'F:\University of Michigan Dropbox\Jiahui Chen\Ford_CC\Result_v2h\Results_80_Y82_2030_nocarb',
    r'F:\University of Michigan Dropbox\Jiahui Chen\Ford_CC\Result_v2h\Results_80_Y82_2040_nocarb',
    r'F:\University of Michigan Dropbox\Jiahui Chen\Ford_CC\Result_v2h_no\Results_2024_60_nocarb',
    r'F:\University of Michigan Dropbox\Jiahui Chen\Ford_CC\Result_v2h_no\Results_2030_60_nocarb',
    r'F:\University of Michigan Dropbox\Jiahui Chen\Ford_CC\Result_v2h_no\Results_2040_60_nocarb',
    r'F:\University of Michigan Dropbox\Jiahui Chen\Ford_CC\Result_v2h_no\Results_2024_noelec_nocarb',
    r'F:\University of Michigan Dropbox\Jiahui Chen\Ford_CC\Result_v2h_no\Results_2030_noelec_nocarb',
    r'F:\University of Michigan Dropbox\Jiahui Chen\Ford_CC\Result_v2h_no\Results_2040_noelec_nocarb'
]

for base_dir in dirs_to_check:
    print(f"\nChecking directory: {base_dir}")
    missing_report = []
    found_missing = False
    for folder in os.listdir(base_dir):
        folder_path = os.path.join(base_dir, folder)
        if os.path.isdir(folder_path):
            files_in_folder = set([f for f in os.listdir(folder_path) if f.endswith('.csv')])
            # For each required file, check if either the _soc or _50 version is present
            missing = []
            for soc, fifty in required_csvs_with_50:
                if soc not in files_in_folder and (fifty is None or fifty not in files_in_folder):
                    missing.append(soc if fifty is None else f"{soc} or {fifty}")
            if missing:
                missing_report.append((folder, missing))
                found_missing = True
                break  # Stop checking further folders if one is missing files
    if missing_report:
        print("Folders with missing required CSVs:")
        for folder, missing in missing_report:
            print(f"{folder}: missing {len(missing)} files")
            for m in missing:
                print(f"    {m}")
    else:
        print("All folders contain all required CSV files.")
# Out:
# Checking directory: F:\University of Michigan Dropbox\Jiahui Chen\Ford_CC\Results\Results_80_82_rev
# All folders contain all required CSV files.
#
# Checking directory: F:\University of Michigan Dropbox\Jiahui Chen\Ford_CC\Result_cc\Results_Y82_2024_rev
# All folders contain all required CSV files.
#
# Checking directory: F:\University of Michigan Dropbox\Jiahui Chen\Ford_CC\Result_cc\Results_Y82_2030_rev
# All folders contain all required CSV files.
#
# Checking directory: F:\University of Michigan Dropbox\Jiahui Chen\Ford_CC\Result_cc\Results_Y82_2040_rev
# All folders contain all required CSV files.
#
# Checking directory: F:\University of Michigan Dropbox\Jiahui Chen\Ford_CC\Result_cc\Results_Y60_2024_nocarb
# All folders contain all required CSV files.
#
# Checking directory: F:\University of Michigan Dropbox\Jiahui Chen\Ford_CC\Result_cc\Results_Y60_2030_nocarb
# All folders contain all required CSV files.
#
# ...
